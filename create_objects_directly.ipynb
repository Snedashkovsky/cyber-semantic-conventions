# %% [markdown]
# ## Create Objects Directly in Cyber

# %%
from IPython.display import Image

from config import WALLET
from src.utils import linking
from src.utils_ipfs import upload_text

# %% [markdown]
# ### Tweet
# #### Create Tweet Object ([Transaction](https://rebyc.cyber.page/network/bostrom/tx/45DC76417B8BFC1149B6E1FD74313269A3EAFBEE53EF3097DCF02C8F88469CAA))

# %%
Image(filename='img/tweet_object.png', width=600)

# %%
tweet_key_cid, _ = upload_text('tweet')
tweet_message_cid, _ = upload_text('Semantic Conventions Research https://github.com/Snedashkovsky/cyber-semantic-conventions')

tweet_link_candidates = \
    [[tweet_key_cid, tweet_message_cid]]

linking(link_candidates=tweet_link_candidates,
        wallet=WALLET,
        sleep_time=4)
# Out:
# Uploading text: tweet
# Uploading text: Semantic Conventions Research https://github.com/Snedashkovsky/cyber-semantic-conventions
# cyberLink from QmbdH2WBamyKLPE5zu4mJ9v49qvY8BFfoumoVPMR5V4Rvx to QmSuChb6nuxaHpq2CR8P9pfwk7ME2GREgkTF815aLzD6D4
# {'code': 0,
#  'codespace': '',
#  'data': '',
#  'hash': 'C7433F48612335A6646CFB22D5BDA24579CB9F29B9FD91F5F27105EAD507A406',
#  'log': '[]'}

# %% [markdown]
# #### Create Tweet Answer Object ([Transaction](https://rebyc.cyber.page/network/bostrom/tx/96832D383D88A3D1E3A4CA177BAAE3799D0514BB2FF7E6A183EDA3171CBF219E))

# %%
Image(filename='img/tweet_answer_object.png', width=600)

# %%
tweet_message_cid, _ = upload_text('Semantic Conventions Research https://github.com/Snedashkovsky/cyber-semantic-conventions')
tweet_answer_cid, _ = upload_text("Let's research this!")

tweet_answer_link_candidates = \
    [[tweet_message_cid, tweet_answer_cid]]

linking(link_candidates=tweet_answer_link_candidates,
        wallet=WALLET,
        sleep_time=4)
# Out:
# Uploading text: Semantic Conventions Research https://github.com/Snedashkovsky/cyber-semantic-conventions
# Uploading text: Let's research this!
# cyberLink from QmSuChb6nuxaHpq2CR8P9pfwk7ME2GREgkTF815aLzD6D4 to QmVHJgep8rTkJTJtJ59RsXKNEp9MQdr2rkPz7EeWvkDvky
# {'code': 0,
#  'codespace': '',
#  'data': '',
#  'hash': '96832D383D88A3D1E3A4CA177BAAE3799D0514BB2FF7E6A183EDA3171CBF219E',
#  'log': '[]'}

# %% [markdown]
# #### Create Tweet Object. Proposed convention ([Transaction](https://rebyc.cyber.page/network/bostrom/tx/7B88195911C18C40EDF8D74F24B94CAE57CBFC82BB620A003F929739580ADB4B))

# %%
Image(filename='img/tweet_answer_object(proposed).png', width=600)

# %%
tweet_message_cid, _ = upload_text('Semantic Conventions Research https://github.com/Snedashkovsky/cyber-semantic-conventions')
tweet_answer_cid, _ = upload_text("Let's research this!")
tweet_answer_key_cid, _ = upload_text("tweet answer")

tweet_answer_proposed_link_candidates = \
    [[tweet_message_cid, tweet_answer_cid],
     [tweet_answer_key_cid, tweet_answer_cid]]

linking(link_candidates=tweet_answer_proposed_link_candidates,
        wallet=WALLET,
        sleep_time=4)
# Out:
# Uploading text: Semantic Conventions Research https://github.com/Snedashkovsky/cyber-semantic-conventions
# Uploading text: Let's research this!
# Uploading text: tweet answer
# cyberLink from QmSuChb6nuxaHpq2CR8P9pfwk7ME2GREgkTF815aLzD6D4 to QmVHJgep8rTkJTJtJ59RsXKNEp9MQdr2rkPz7EeWvkDvky
# cyberLink from QmXxCVgN8WZi6QtF8x8u1pQsvVgLpi81pgjjwtHt1kQ8Ax to QmVHJgep8rTkJTJtJ59RsXKNEp9MQdr2rkPz7EeWvkDvky
# {'code': 0,
#  'codespace': '',
#  'data': '',
#  'hash': '7B88195911C18C40EDF8D74F24B94CAE57CBFC82BB620A003F929739580ADB4B',
#  'log': '[]'}

# %% [markdown]
# <a id=’follow’></a>
# ### Follow
# #### Create Follow Object ([Transaction](https://rebyc.cyber.page/network/bostrom/tx/13D76B4F9F7BDDFC11EDA25887E225E31EE59C2C67CD884D1789C638EEB3D110))

# %%
Image(filename='img/follow_object.png', width=600)

# %%
follow_key_cid, _ = upload_text('follow')
account_address_cid, _ = upload_text('bostrom1quchyywzdxp62dq3rwan8fg35v6j58sjwnfpuu'.lower())

follow_link_candidates = \
    [[follow_key_cid, account_address_cid]]

linking(link_candidates=follow_link_candidates,
        wallet=WALLET,
        sleep_time=4)
# Out:
# Uploading text: follow
# Uploading text: bostrom1quchyywzdxp62dq3rwan8fg35v6j58sjwnfpuu
# cyberLink from QmPLSA5oPqYxgc8F7EwrM8WS9vKrr1zPoDniSRFh8HSrxx to QmNqzt864DpEaL6W2qdhthXWEhYaaP4j9qhjULtWWDbRLd
# {'code': 0,
#  'codespace': '',
#  'data': '',
#  'hash': '13D76B4F9F7BDDFC11EDA25887E225E31EE59C2C67CD884D1789C638EEB3D110',
#  'log': '[]'}

# %% [markdown]
# #### Create Unfollow Object ([Transaction](https://rebyc.cyber.page/network/bostrom/tx/F8A5BAB4C7A7F26453A5B4F3448C45D8DEF6A47E3372AF123A44A31466DA82A1))

# %%
Image(filename='img/unfollow_object.png', width=600)

# %%
unfollow_key_cid, _ = upload_text('unfollow')
account_address_cid, _ = upload_text('bostrom1quchyywzdxp62dq3rwan8fg35v6j58sjwnfpuu'.lower())

unfollow_link_candidates = \
    [[unfollow_key_cid, account_address_cid]]

linking(link_candidates=unfollow_link_candidates,
        wallet=WALLET,
        sleep_time=4)
# Out:
# Uploading text: unfollow
# Uploading text: bostrom1quchyywzdxp62dq3rwan8fg35v6j58sjwnfpuu
# cyberLink from QmRsRWy8K9Sb5bsHDzTUD1mtXjk5rgtXM2xi4dqmN529kM to QmNqzt864DpEaL6W2qdhthXWEhYaaP4j9qhjULtWWDbRLd
# {'code': 0,
#  'codespace': '',
#  'data': '',
#  'hash': 'F8A5BAB4C7A7F26453A5B4F3448C45D8DEF6A47E3372AF123A44A31466DA82A1',
#  'log': '[]'}

# %% [markdown]
# ### Avatar
# #### Create Avatar Class ([Transaction](https://rebyc.cyber.page/network/bostrom/tx/FE15AF00777264712C633D3B4C22BFCD979BE3C646745226BCCEE09D3B31531F))

# %%
Image(filename='img/avatar_class.png', width=600)

# %%
avatar_key_cid, _ = upload_text('avatar')
avatar_class_cid, _ = upload_text('avatar name')

avatar_class_link_candidates = \
    [[avatar_key_cid, avatar_class_cid]]

linking(link_candidates=avatar_class_link_candidates,
        wallet=WALLET,
        sleep_time=4)
# Out:
# Uploading text: avatar
# Uploading text: avatar name
# cyberLink from Qmf89bXkJH9jw4uaLkHmZkxQ51qGKfUPtAMxA8rTwBrmTs to QmbteQvDFdMLS7Uf24F7j4rAZNSqinT74yygUhNWr2RaC2
# {'code': 0,
#  'codespace': '',
#  'data': '',
#  'hash': 'FE15AF00777264712C633D3B4C22BFCD979BE3C646745226BCCEE09D3B31531F',
#  'log': '[]'}

# %% [markdown]
# #### Create Avatar Object ([Transaction](https://rebyc.cyber.page/network/bostrom/tx/72DDEE4104007DD1EAFC6A6436F192740C5AAAFEE3CB7DAD9EEBD8FABE12543C))

# %%
Image(filename='img/avatar_object.png', width=600)

# %%
avatar_class_cid, _ = upload_text('avatar name')
avatar_item_cid, _ = upload_text('semantic researcher')

avatar_link_candidates = \
    [[avatar_class_cid, avatar_item_cid]]

linking(link_candidates=avatar_link_candidates,
        wallet=WALLET,
        sleep_time=4)
# Out:
# Uploading text: avatar name
# Uploading text: semantic researcher
# cyberLink from QmbteQvDFdMLS7Uf24F7j4rAZNSqinT74yygUhNWr2RaC2 to QmcEcCLTbQbZVyBVZX7BxHoXon5HxZdV1MZ22hY1dKkSQM
# {'code': 0,
#  'codespace': '',
#  'data': '',
#  'hash': '72DDEE4104007DD1EAFC6A6436F192740C5AAAFEE3CB7DAD9EEBD8FABE12543C',
#  'log': '[]'}

# %% [markdown]
# ### Favorites
# #### Create Favorite Class ([Transaction](https://rebyc.cyber.page/network/bostrom/tx/E0E09C89C5EF320F28865F9059AE16CF3B97FF64D89B9FBC6A725F20875A51C6))

# %%
Image(filename='img/favorite_class.png', width=600)

# %%
favorite_key_cid, _ = upload_text('favorite')
favorite_class_cid, _ = upload_text('favorite name')

favorite_class_link_candidates = \
    [[favorite_key_cid, favorite_class_cid]]

linking(link_candidates=favorite_class_link_candidates,
        wallet=WALLET,
        sleep_time=4)
# Out:
# Uploading text: favorite
# Uploading text: favorite name
# cyberLink from QmRU8Tz93jmiHEJcTz7GbmuJ6N3DxS8jzqDAp2c9UAK4mR to QmbWLFqpQo1fUPnTsM4jP9aipugMXNAKSDovQLVNV4a4ai
# {'code': 0,
#  'codespace': '',
#  'data': '',
#  'hash': 'E0E09C89C5EF320F28865F9059AE16CF3B97FF64D89B9FBC6A725F20875A51C6',
#  'log': '[]'}

# %% [markdown]
# #### Create Favorite Object ([Transaction](https://rebyc.cyber.page/network/bostrom/tx/735AF99AE9C1678A7C5DD855383497182AFA842CF5BD7A317FD7BCB6B2D1D78C))

# %%
Image(filename='img/favorite_object.png', width=600)

# %%
favorite_class_cid, _ = upload_text('favorite name')
favorite_item_cid, _ = upload_text('semantic research')

favorite_link_candidates = \
    [[favorite_class_cid, favorite_item_cid]]

linking(link_candidates=favorite_link_candidates,
        wallet=WALLET,
        sleep_time=4)
# Out:
# Uploading text: favorite name
# Uploading text: semantic research
# cyberLink from QmbWLFqpQo1fUPnTsM4jP9aipugMXNAKSDovQLVNV4a4ai to QmenXHsWGaEaAnbXRTu4P129rpKkdvzuL3qfo5J694QPiE
# {'code': 0,
#  'codespace': '',
#  'data': '',
#  'hash': '735AF99AE9C1678A7C5DD855383497182AFA842CF5BD7A317FD7BCB6B2D1D78C',
#  'log': '[]'}

# %% [markdown]
# ### Data Type
# #### Initialize of a Data Type ([Transaction](https://rebyc.cyber.page/network/bostrom/tx/43666E5C5E0716C87A663786A71E226613AD566633DEEF220D862FB1E8FB868F))

# %%
Image(filename='img/data_type_class.png', width=600)

# %%
data_type_key_cid, _ = upload_text('data type')
data_type_cid, _ = upload_text('data type string')

data_type_class_link_candidates = \
    [[data_type_key_cid, data_type_cid]]

linking(link_candidates=data_type_class_link_candidates,
        wallet=WALLET,
        sleep_time=4)
# Out:
# Uploading text: data type
# Uploading text: data type string
# cyberLink from Qma48asT7GaA5CWQhqx5zTgdX773CaL7tJ9the6KZpu1j1 to QmWnQPYERRL3GejpnbLEPFRQd1big8KdZGZMvHm8TCjSDH
# {'code': 0,
#  'codespace': '',
#  'data': '',
#  'hash': '43666E5C5E0716C87A663786A71E226613AD566633DEEF220D862FB1E8FB868F',
#  'log': '[]'}

# %% [markdown]
# #### Link Object with a Data Type ([Transaction](https://rebyc.cyber.page/network/bostrom/tx/1425DA72E0EC71565BA706BFB3414481634C129C8D2835175F42E5C28389EB2B))

# %%
Image(filename='img/data_type_object.png', width=600)

# %%
data_type_cid, _ = upload_text('data type string')
data_type_item_cid, _ = upload_text('example of string')

data_type_link_candidates = \
    [[data_type_cid, data_type_item_cid]]

linking(link_candidates=data_type_link_candidates,
        wallet=WALLET,
        sleep_time=4)
# Out:
# Uploading text: data type string
# Uploading text: example of string
# cyberLink from QmWnQPYERRL3GejpnbLEPFRQd1big8KdZGZMvHm8TCjSDH to QmWraLrGL9rejnNc1ZXY36wrkPgpbcGv3BtyHAoJcSFUHV
# {'code': 0,
#  'codespace': '',
#  'data': '',
#  'hash': '1425DA72E0EC71565BA706BFB3414481634C129C8D2835175F42E5C28389EB2B',
#  'log': '[]'}
