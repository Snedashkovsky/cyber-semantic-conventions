# %% [markdown]
# ## Create Tweet Object in Cyber by Semantic Conventions

# %%
from IPython.display import Image
from cyberpy import generate_wallet

from config import WALLET
from src.utils import linking
from src.utils_ipfs import upload_text

CREATE_WALLET = False

wallet = generate_wallet() if CREATE_WALLET else WALLET

# %% [markdown]
# ### Create Tweet Object ([Transaction](https://rebyc.cyber.page/network/bostrom/tx/45DC76417B8BFC1149B6E1FD74313269A3EAFBEE53EF3097DCF02C8F88469CAA))

# %%
Image(filename='img/tweet_object.png')

# %%
tweet_key_cid = upload_text('tweet')
tweet_message_cid = upload_text('Semantic Conventions Research https://github.com/Snedashkovsky/cyber-semantic-conventions')

tweet_link_candidates = \
    [[tweet_key_cid, tweet_message_cid]]

linking(link_candidates=tweet_link_candidates,
        wallet=WALLET,
        sleep_time=4)
# Out:
# {
#   "jsonrpc": "2.0",
#   "id": 1,
#   "result": {
#     "code": 0,
#     "data": "",
#     "log": "[]",
#     "codespace": "",
#     "hash": "45DC76417B8BFC1149B6E1FD74313269A3EAFBEE53EF3097DCF02C8F88469CAA"
#   }
# }

# %% [markdown]
# ### Definition of the Tweet Semantic Convention by JSON ([Transaction](https://rebyc.cyber.page/network/bostrom/tx/3EE04317DE0AFEDAA826CC24A6062BC89339B9CF7F780E33ADC04E8A823F8EEE))

# %%
Image(filename='img/tweet_json_definition.png')

# %%
link_candidates_semantic_convention_json = \
    [['QmbCq4d3CdvSSx9NHPrVM9WxA9uj36CE5RyzY18gxfrXxS', 'QmfPbUnGPsPUPXSAWW6DqsbCWpURANfg7HWY6MbpE55Shs']]

linking(link_candidates_semantic_convention_json,
        wallet=wallet,
        sleep_time=4)
# Out:
# {
#   "jsonrpc": "2.0",
#   "id": 1,
#   "result": {
#     "code": 0,
#     "data": "",
#     "log": "[]",
#     "codespace": "",
#     "hash": "DD2EB4010EAE873A63761C4942087E4994F08304EDD4BC7E6812E6DB4E4763CD"
#   }
# }

# %% [markdown]
# ### Definition of the Tweet Semantic Convention by cyberLinks ([Transaction](https://rebyc.cyber.page/network/bostrom/tx/A97A7621EFC07C0038FA5B1A9BA328FC3CCF1A5775141256855E4285A061BB27))

# %%
Image(filename='img/tweet_cyberlinks_definition.png')

# %%
link_candidates_semantic_convention_cyberlinks = \
    [['QmbCq4d3CdvSSx9NHPrVM9WxA9uj36CE5RyzY18gxfrXxS', 'QmbdH2WBamyKLPE5zu4mJ9v49qvY8BFfoumoVPMR5V4Rvx'],
     ['QmbdH2WBamyKLPE5zu4mJ9v49qvY8BFfoumoVPMR5V4Rvx', 'QmVbZDBGBxWkwHXbcA3nj3L5psHU7TMruT7VnvCHq4gHVF'],
     ['QmbdH2WBamyKLPE5zu4mJ9v49qvY8BFfoumoVPMR5V4Rvx', 'QmRgdL8wLxRcvvGpTtBbRY8gfeSL6Nw3Po1GNCfCctCASJ'],
     ['QmbdH2WBamyKLPE5zu4mJ9v49qvY8BFfoumoVPMR5V4Rvx', 'QmSKSUnhTVGngEXungHUqgGRQdRzmvUG48qX96BGDfyU1W'],
     ['QmSKSUnhTVGngEXungHUqgGRQdRzmvUG48qX96BGDfyU1W', 'QmbdH2WBamyKLPE5zu4mJ9v49qvY8BFfoumoVPMR5V4Rvx'],
     ['QmbdH2WBamyKLPE5zu4mJ9v49qvY8BFfoumoVPMR5V4Rvx', 'Qmag1daF9F2KrrR7dNLoB98tkrjpVFKrTX5FZkBtqz7men']]

linking(link_candidates_semantic_convention_cyberlinks,
        wallet=wallet)
# Out:
# {
#   "jsonrpc": "2.0",
#   "id": 1,
#   "result": {
#     "code": 0,
#     "data": "",
#     "log": "[]",
#     "codespace": "",
#     "hash": "451F226EC072F258EF6AD3094DAFD19401619DBB7A8E9C9815EF8289D985C27B"
#   }
# }
